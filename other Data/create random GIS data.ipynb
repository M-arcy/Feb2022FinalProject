# %%
import random
import sys
import math
#lat and longitude of Ames, IA is 42.034534, -93.620369  +/-  but what is DMS lat and DMS long?

# %% [markdown]
# #### latitude = 42.034534
# longitude = -93.620369
# file_n = 'randomLatLong.csv'
#
# def generate_random_data(lat, lon, num_rows, file_name):
#     with open(file_name, 'w') as output:
#         for _ in xrange(num_rows):
#             hex1 = '%012x' % random.randrange(16**12)
#             flt = float(random.randint(0,100))
#             dec_lat = random.random()/100
#             dec_lon = random.random()/100
#             output.write('%s,%.1f,%.6f,%.6f \n' % (hex1.lower(), flt, lon+dec_lon, lat+dec_lat))
#
# generate_random_data(latitude, longitude, 600, file_n)

# %% [markdown]
# ###file_n = 'randomLatLong.csv'
# def random_lat_lon(n=1, lat_min=42.014534, lat_max=42.03500, lon_min=-93.620369, lon_max=-93.620400):
#     """ this code produces an array with pairs lat, lon """
#     with open(file_name, 'w') as output:
#         lat = np.random.uniform(lat_min, lat_max, n)
#         lon = np.random.uniform(lon_min, lon_max, n)
#         output.write('%s,%.1f,%.6f,%.6f \n' % (hex1.lower(), flt, lon+dec_lon, lat+dec_lat))
#     return np.array(tuple(zip(lat, lon)))

# %%
import pandas as pd
import numpy as np

#change n to number of rows of dataframe your trying to append these columns too
n=1460
lat_min, lat_max = 42.014534, 42.03500 
lon_min, lon_max = -93.620369, -93.620400

rand_lat = np.random.uniform(low=lat_min, high= lat_max, size=n)
rand_lon = np.random.uniform(low=lon_min, high= lon_max, size=n)

lat_lon_df = pd.DataFrame(data={"Lat":rand_lat, "Lon":rand_lon})

lat_lon_df.to_csv("random_lat_lon.csv", index=False)

# %%
randomlat = pd.read_csv("C:/Users/Marcy/Documents/Entity Coursework/Final Project/random_lat_lon.csv")

# %%
randomlat.head()
# Out:
#          Lat        Lon
# 0  42.017280 -93.620389
# 1  42.017591 -93.620398
# 2  42.015700 -93.620399
# 3  42.016940 -93.620375
# 4  42.031331 -93.620390

# %%
import pandas as pd
import numpy as np
house = pd.read_csv("C:/Users/Marcy/Desktop/data sets/Housing Data/train.csv")

# %% [markdown]
# ## Drop unnecessary columns

# %%
house.drop(columns= ['Alley', 'LotShape', 'LandContour', 'Utilities', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'MasVnrArea', 'BsmtExposure', 'PoolQC', 'MoSold', 'YrSold'], axis=1, inplace=True)

# %% [markdown]
# ## Recoding

# %%
#Find the object values 
obj_house = house.select_dtypes(include=['object']).copy()
obj_house.head()
# Out:
#   MSZoning Street LotConfig BldgType HouseStyle RoofStyle RoofMatl  \
# 0       RL   Pave    Inside     1Fam     2Story     Gable  CompShg
# 1       RL   Pave       FR2     1Fam     1Story     Gable  CompShg
# 2       RL   Pave    Inside     1Fam     2Story     Gable  CompShg
# 3       RL   Pave    Corner     1Fam     2Story     Gable  CompShg
# 4       RL   Pave       FR2     1Fam     2Story     Gable  CompShg
#
#   Exterior1st Exterior2nd MasVnrType  ... FireplaceQu GarageType GarageFinish  \
# 0     VinylSd     VinylSd    BrkFace  ...         NaN     Attchd          RFn
# 1     MetalSd     MetalSd       None  ...          TA     Attchd          RFn
# 2     VinylSd     VinylSd    BrkFace  ...          TA     Attchd          RFn
# 3     Wd Sdng     Wd Shng       None  ...          Gd     Detchd          Unf
# 4     VinylSd     VinylSd    BrkFace  ...          TA     Attchd          RFn
#
#   GarageQual GarageCond PavedDrive Fence MiscFeature SaleType SaleCondition
# ...

# %%
#Look for null values to clean up first
obj_house[obj_house.isnull().any(axis=1)]
# Out:
#      MSZoning Street LotConfig BldgType HouseStyle RoofStyle RoofMatl  \
# 0          RL   Pave    Inside     1Fam     2Story     Gable  CompShg
# 1          RL   Pave       FR2     1Fam     1Story     Gable  CompShg
# 2          RL   Pave    Inside     1Fam     2Story     Gable  CompShg
# 3          RL   Pave    Corner     1Fam     2Story     Gable  CompShg
# 4          RL   Pave       FR2     1Fam     2Story     Gable  CompShg
# ...       ...    ...       ...      ...        ...       ...      ...
# 1454       FV   Pave    Inside     1Fam     1Story     Gable  CompShg
# 1455       RL   Pave    Inside     1Fam     2Story     Gable  CompShg
# 1456       RL   Pave    Inside     1Fam     1Story     Gable  CompShg
# 1458       RL   Pave    Inside     1Fam     1Story       Hip  CompShg
# 1459       RL   Pave    Inside     1Fam     1Story     Gable  CompShg
#
#      Exterior1st Exterior2nd MasVnrType  ... FireplaceQu GarageType  \
# ...

# %%
#houseR[['MSZoningR', 'StreetR', 'LotConfigR', 'BldgTypeR', 'HouseStyleR', 'RoofStyleR', 'RoofMatlR', 'Exterior1stR', 'Exterior2ndR', 'MasVnrTypeR', 'ExterQualR', 'ExterCondR', 'FoundationR', 'BsmtQualR', 'BsmtCondR', 'BsmtFinType1R', 'BsmtFinSF1R', 'BsmtFinType2R', 'HeatingR', 'HeatingQCR', 'Central AirR', 'ElectricalR', 'KitchenQualR', 'FunctionalR', 'FireplaceQuR', 'GarageTypeR', 'GarageQualR', 'GarageCondR', 'PavedDriveR', 'FenceR', 'MiscFeatureR', 'SaleTypeR', 'SaleConditionR' ] = house[['MSZoning', 'Street', 'LotConfig', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'Central Air', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageQual', 'GarageCond', 'PavedDrive', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']].apply(recode)

# %%
house.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('O'), dtype('float64')], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
list1= house.select_dtypes("O")
list_objects = []
for i in list1:
    list_objects.append(i)
    
    
    
for i in list_objects:
    house[i] = le.fit_transform(house[i])

# %%
house.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotConfig  \
# 0   1          60         3         65.0     8450       1          4
# 1   2          20         3         80.0     9600       1          2
# 2   3          60         3         68.0    11250       1          4
# 3   4          70         3         60.0     9550       1          0
# 4   5          60         3         84.0    14260       1          2
#
#    BldgType  HouseStyle  OverallQual  ...  EnclosedPorch  3SsnPorch  \
# 0         0           5            7  ...              0          0
# 1         0           2            6  ...              0          0
# 2         0           5            7  ...              0          0
# 3         0           5            7  ...            272          0
# 4         0           5            8  ...              0          0
#
#    ScreenPorch  PoolArea  Fence  MiscFeature  MiscVal  SaleType  \
# 0            0         0      4            4        0         8
# ...

# %%
house.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('int32'), dtype('float64')], dtype=object)

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 68 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int32
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int32
#  6   LotConfig      1460 non-null   int32
#  7   BldgType       1460 non-null   int32
#  8   HouseStyle     1460 non-null   int32
#  9   OverallQual    1460 non-null   int64
#  10  OverallCond    1460 non-null   int64
#  11  YearBuilt      1460 non-null   int64
#  12  YearRemodAdd   1460 non-null   int64
#  13  RoofStyle      1460 non-null   int32
#  14  RoofMatl       1460 non-null   int32
#  15  Exterior1st    1460 non-null   int32
#  16  Exterior2nd    1460 non-null   int32
#  17  MasVnrType     1460 non-null   int32
# ...

# %%
#pandas has factorize, sklearn also has onehotencoding -
